# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics opencv-python matplotlib tensorflow numpy pandas
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.127-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading ultralytics-8.3.127-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 38.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 105.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 80.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 89.3 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.127 ultralytics-thop-2.0.14

# %%
# !unzip "/content/drive/MyDrive/Traffic_Sign_Recognition/ML_Dataset/gtsdb.zip" -d "/content/gtsdb"
# Out:
# Archive:  /content/drive/MyDrive/Traffic_Sign_Recognition/ML_Dataset/gtsdb.zip
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00000.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00001.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00002.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00003.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00004.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00005.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00006.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00007.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00008.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00009.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00010.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00011.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00012.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00013.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00014.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00015.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00016.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00017.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00018.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00019.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00020.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00021.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00022.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00023.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00024.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00025.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00026.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00027.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00028.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00029.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00030.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00031.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00032.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00033.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00034.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00035.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00036.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00037.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00038.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00039.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00040.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00041.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00042.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00043.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00044.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00045.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00046.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00047.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00048.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00049.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00050.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00051.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00052.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00053.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00054.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00055.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00056.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00057.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00058.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00059.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00060.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00061.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00062.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00063.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00064.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00065.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00066.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00067.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00068.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00069.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00070.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00071.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00072.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00073.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00074.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00075.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00076.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00077.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00078.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00079.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00080.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00081.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00082.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00083.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00084.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00085.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00086.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00087.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00088.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00089.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00090.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00091.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00092.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00093.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00094.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00095.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00096.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00097.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00098.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00099.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00100.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00101.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00102.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00103.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00104.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00105.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00106.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00107.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00108.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00109.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00110.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00111.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00112.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00113.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00114.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00115.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00116.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00117.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00118.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00119.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00120.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00121.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00122.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00123.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00124.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00125.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00126.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00127.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00128.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00129.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00130.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00131.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00132.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00133.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00134.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00135.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00136.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00137.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00138.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00139.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00140.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00141.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00142.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00143.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00144.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00145.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00146.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00147.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00148.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00149.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00150.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00151.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00152.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00153.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00154.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00155.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00156.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00157.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00158.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00159.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00160.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00161.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00162.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00163.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00164.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00165.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00166.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00167.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00168.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00169.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00170.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00171.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00172.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00173.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00174.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00175.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00176.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00177.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00178.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00179.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00180.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00181.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00182.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00183.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00184.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00185.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00186.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00187.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00188.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00189.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00190.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00191.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00192.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00193.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00194.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00195.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00196.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00197.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00198.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00199.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00200.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00201.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00202.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00203.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00204.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00205.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00206.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00207.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00208.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00209.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00210.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00211.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00212.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00213.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00214.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00215.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00216.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00217.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00218.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00219.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00220.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00221.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00222.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00223.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00224.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00225.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00226.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00227.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00228.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00229.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00230.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00231.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00232.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00233.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00234.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00235.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00236.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00237.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00238.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00239.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00240.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00241.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00242.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00243.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00244.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00245.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00246.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00247.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00248.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00249.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00250.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00251.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00252.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00253.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00254.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00255.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00256.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00257.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00258.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00259.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00260.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00261.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00262.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00263.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00264.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00265.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00266.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00267.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00268.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00269.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00270.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00271.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00272.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00273.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00274.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00275.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00276.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00277.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00278.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00279.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00280.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00281.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00282.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00283.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00284.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00285.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00286.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00287.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00288.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00289.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00290.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00291.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00292.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00293.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00294.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00295.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00296.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00297.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00298.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/00299.ppm
#   inflating: /content/gtsdb/TestIJCNN2013/TestIJCNN2013Download/ReadMe.txt
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00/00000.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00/00001.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00/00002.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00/00003.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00000.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00001.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00002.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00003.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00004.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00005.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00006.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00007.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00008.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00009.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00010.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00011.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00012.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00013.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00014.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00015.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00016.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00017.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00018.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00019.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00020.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00021.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00022.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00023.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00024.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00025.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00026.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00027.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00028.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00029.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00030.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00031.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00032.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00033.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00034.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00035.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00036.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00037.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00038.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00039.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00040.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00041.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00042.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00043.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00044.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00045.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00046.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00047.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00048.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00049.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00050.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00051.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00052.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00053.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00054.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00055.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00056.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00057.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00058.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00059.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00060.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00061.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00062.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00063.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00064.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00065.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00066.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00067.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00068.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00069.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00070.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00071.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00072.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00073.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00074.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00075.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00076.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00077.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00078.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00079.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00080.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00081.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00082.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00083.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00084.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00085.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00086.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00087.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00088.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00089.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00090.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00091.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00092.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00093.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00094.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00095.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00096.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00097.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00098.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00099.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00100.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00101.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00102.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00103.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00104.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00105.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00106.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00107.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00108.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00109.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00110.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00111.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00112.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00113.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00114.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00115.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00116.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00117.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00118.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00119.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00120.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00121.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00122.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00123.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00124.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00125.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00126.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00127.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00128.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00129.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00130.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00131.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00132.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00133.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00134.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00135.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00136.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00137.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00138.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00139.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00140.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00141.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00142.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00143.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00144.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00145.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00146.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00147.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00148.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00149.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00150.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00151.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00152.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00153.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00154.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00155.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00156.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00157.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00158.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00159.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00160.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00161.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00162.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00163.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00164.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00165.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00166.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00167.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00168.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00169.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00170.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00171.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00172.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00173.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00174.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00175.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00176.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00177.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00178.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00179.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00180.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00181.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00182.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00183.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00184.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00185.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00186.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00187.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00188.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00189.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00190.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00191.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00192.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00193.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00194.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00195.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00196.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00197.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00198.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00199.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00200.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00201.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00202.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00203.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00204.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00205.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00206.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00207.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00208.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00209.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00210.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00211.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00212.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00213.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00214.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00215.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00216.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00217.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00218.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00219.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00220.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00221.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00222.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00223.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00224.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00225.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00226.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00227.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00228.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00229.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00230.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00231.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00232.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00233.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00234.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00235.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00236.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00237.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00238.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00239.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00240.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00241.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00242.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00243.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00244.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00245.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00246.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00247.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00248.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00249.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00250.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00251.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00252.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00253.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00254.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00255.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00256.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00257.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00258.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00259.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00260.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00261.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00262.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00263.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00264.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00265.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00266.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00267.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00268.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00269.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00270.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00271.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00272.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00273.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00274.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00275.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00276.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00277.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00278.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00279.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00280.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00281.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00282.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00283.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00284.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00285.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00286.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00287.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00288.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00289.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00290.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00291.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00292.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00293.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00294.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00295.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00296.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00297.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00298.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00299.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00300.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00301.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00302.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00303.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00304.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00305.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00306.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00307.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00308.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00309.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00310.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00311.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00312.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00313.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00314.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00315.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00316.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00317.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00318.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00319.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00320.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00321.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00322.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00323.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00324.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00325.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00326.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00327.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00328.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00329.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00330.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00331.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00332.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00333.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00334.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00335.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00336.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00337.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00338.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00339.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00340.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00341.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00342.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00343.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00344.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00345.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00346.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00347.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00348.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00349.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00350.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00351.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/00352.ppm
# ...
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/22/00003.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/22/00004.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/22/00005.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/22/00006.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/22/00007.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/22/00008.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/23/00000.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/23/00001.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/23/00002.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/23/00003.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/23/00004.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/23/00005.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/23/00006.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/23/00007.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/23/00008.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/23/00009.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/23/00010.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/23/00011.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/23/00012.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/24/00000.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/24/00001.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/25/00000.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/25/00001.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/25/00002.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/25/00003.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/25/00004.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/25/00005.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/25/00006.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/25/00007.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/25/00008.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/25/00009.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/25/00010.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/25/00011.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/25/00012.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/25/00013.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/25/00014.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/25/00015.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/25/00016.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/25/00017.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/25/00018.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/25/00019.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/25/00020.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/26/00000.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/26/00001.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/26/00002.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/26/00003.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/26/00004.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/26/00005.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/26/00006.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/26/00007.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/26/00008.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/26/00009.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/26/00010.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/27/00000.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/27/00001.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/27/00002.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/28/00000.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/28/00001.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/28/00002.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/28/00003.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/28/00004.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/28/00005.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/28/00006.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/28/00007.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/28/00008.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/29/00000.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/29/00001.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/29/00002.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/29/00003.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/30/00000.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/30/00001.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/30/00002.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/30/00003.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/30/00004.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/30/00005.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/30/00006.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/30/00007.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/30/00008.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/30/00009.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/30/00010.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/30/00011.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/30/00012.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/30/00013.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/31/00000.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/32/00000.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/32/00001.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/32/00002.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/33/00000.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/33/00001.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/33/00002.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/33/00003.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/33/00004.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/33/00005.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/33/00006.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/33/00007.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/33/00008.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/33/00009.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/33/00010.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/33/00011.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/33/00012.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/34/00000.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/34/00001.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/34/00002.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/34/00003.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/34/00004.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/34/00005.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/34/00006.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/34/00007.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/34/00008.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/35/00000.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/35/00001.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/35/00002.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/35/00003.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/35/00004.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/35/00005.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/35/00006.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/35/00007.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/35/00008.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/35/00009.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/35/00010.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/35/00011.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/35/00012.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/35/00013.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/35/00014.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/36/00000.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/36/00001.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/36/00002.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/36/00003.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/36/00004.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/36/00005.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/36/00006.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/36/00007.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/37/00000.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00000.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00001.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00002.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00003.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00004.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00005.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00006.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00007.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00008.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00009.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00010.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00011.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00012.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00013.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00014.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00015.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00016.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00017.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00018.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00019.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00020.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00021.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00022.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00023.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00024.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00025.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00026.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00027.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00028.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00029.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00030.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00031.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00032.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00033.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00034.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00035.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00036.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00037.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00038.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00039.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00040.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00041.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00042.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00043.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00044.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00045.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00046.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00047.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00048.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00049.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00050.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00051.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00052.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00053.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00054.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00055.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/38/00056.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/39/00000.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/39/00001.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/39/00002.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/39/00003.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/40/00000.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/40/00001.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/40/00002.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/40/00003.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/40/00004.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/40/00005.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/40/00006.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/40/00007.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/41/00000.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/41/00001.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/41/00002.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/41/00003.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/41/00004.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/41/00005.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/42/00000.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/42/00001.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/42/00002.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/42/00003.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/42/00004.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/42/00005.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/42/00006.ppm
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/ReadMe.txt
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/ex.txt
#   inflating: /content/gtsdb/TrainIJCNN2013/TrainIJCNN2013/gt.txt
#   inflating: /content/gtsdb/gt.txt

# %%
import os
import shutil
from PIL import Image
import torch
from ultralytics import YOLO
import pandas as pd
from collections import Counter


def prepare_gtsdb_dataset():
    input_file = "/content/gtsdb/gt.txt"
    base_images_dir = "/content/gtsdb/TrainIJCNN2013/TrainIJCNN2013"
    output_dir = "/content/gtsdb_yolo"

    dirs = {
        'train': os.path.join(output_dir, 'train'),
        'val': os.path.join(output_dir, 'val')
    }

    for d in dirs.values():
        os.makedirs(os.path.join(d, 'images'), exist_ok=True)
        os.makedirs(os.path.join(d, 'labels'), exist_ok=True)

    annotations = {}
    with open(input_file, "r") as f:
        for line in f:
            parts = line.strip().split(";")
            if len(parts) != 6:
                continue

            img_file = parts[0]
            if img_file not in annotations:
                annotations[img_file] = []

            try:
                x_min, y_min, x_max, y_max, class_id = map(int, parts[1:])
                annotations[img_file].append((x_min, y_min, x_max, y_max, class_id))
            except ValueError:
                print(f"Skipping malformed line: {line.strip()}")
                continue

    processed_count = 0
    skipped_count = 0

    for i, (img_file, bboxes) in enumerate(annotations.items()):
        img_path = os.path.join(base_images_dir, img_file)

        if not os.path.exists(img_path):
            print(f"Warning: Missing image {img_file}")
            skipped_count += 1
            continue

        try:
            with Image.open(img_path) as img:
                img_width, img_height = img.size

                label_file = img_file.replace(".ppm", ".txt")
                split = 'val' if i % 10 == 0 else 'train'

                valid_bboxes = []
                for x_min, y_min, x_max, y_max, class_id in bboxes:
                    x_min = max(0, min(x_min, img_width - 1))
                    y_min = max(0, min(y_min, img_height - 1))
                    x_max = max(0, min(x_max, img_width - 1))
                    y_max = max(0, min(y_max, img_height - 1))

                    width = x_max - x_min
                    height = y_max - y_min

                    if width <= 0 or height <= 0:
                        print(f"Invalid bbox in {img_file}: {x_min},{y_min},{x_max},{y_max}")
                        continue

                    x_center = (x_min + width / 2) / img_width
                    y_center = (y_min + height / 2) / img_height
                    norm_width = width / img_width
                    norm_height = height / img_height

                    if (0 <= x_center <= 1 and 0 <= y_center <= 1 and
                        0 < norm_width <= 1 and 0 < norm_height <= 1):
                        valid_bboxes.append(f"{class_id} {x_center:.6f} {y_center:.6f} {norm_width:.6f} {norm_height:.6f}")
                    else:
                        print(f"Invalid normalized bbox in {img_file}: {x_center:.2f},{y_center:.2f},{norm_width:.2f},{norm_height:.2f}")

                if valid_bboxes:
                    with open(os.path.join(dirs[split], 'labels', label_file), 'w') as f:
                        f.write("\n".join(valid_bboxes))

                    jpg_file = img_file.replace(".ppm", ".jpg")
                    img.convert("RGB").save(os.path.join(dirs[split], 'images', jpg_file), "JPEG")
                    processed_count += 1
                else:
                    print(f"Skipping {img_file} - no valid bboxes")
                    skipped_count += 1

        except Exception as e:
            print(f"Error processing {img_file}: {str(e)}")
            skipped_count += 1

    print(f"✅ Dataset preparation complete! Processed: {processed_count}, Skipped: {skipped_count}")
    return output_dir



def analyze_dataset(dataset_path):
    print("\n📊 Dataset Analysis:")

    for split in ['train', 'val']:
        img_dir = os.path.join(dataset_path, split, 'images')
        label_dir = os.path.join(dataset_path, split, 'labels')

        num_images = len([f for f in os.listdir(img_dir) if f.endswith(('.jpg'))])
        num_labels = len([f for f in os.listdir(label_dir) if f.endswith('.txt')])
        print(f"{split.upper()}: {num_images} images, {num_labels} label files")
        img_files = {os.path.splitext(f)[0] for f in os.listdir(img_dir) if f.endswith(('.jpg', '.png', '.jpeg'))}
        label_files = {os.path.splitext(f)[0] for f in os.listdir(label_dir) if f.endswith('.txt')}

        missing_labels = img_files - label_files
        missing_images = label_files - img_files

        if missing_labels:
            print(f"  ⚠️ Missing labels for {len(missing_labels)} images")
        if missing_images:
            print(f"  ⚠️ Missing images for {len(missing_images)} labels")

    def count_classes(label_dir):
        class_counts = Counter()
        for label_file in os.listdir(label_dir):
            if not label_file.endswith('.txt'):
                continue
            try:
                with open(os.path.join(label_dir, label_file)) as f:
                    for line in f:
                        parts = line.strip().split()
                        if len(parts) == 5:  # class, x, y, w, h
                            class_id = int(parts[0])
                            class_counts[class_id] += 1
            except Exception as e:
                print(f"Error reading {label_file}: {e}")
        return class_counts

    print("\n🔢 Class Distribution:")
    train_counts = count_classes(os.path.join(dataset_path, 'train', 'labels'))
    val_counts = count_classes(os.path.join(dataset_path, 'val', 'labels'))

    class_df = pd.DataFrame({
        'Class ID': list(train_counts.keys()),
        'Train Count': list(train_counts.values()),
        'Val Count': [val_counts.get(k, 0) for k in train_counts.keys()]
    }).sort_values('Class ID')

    print("\nClass Distribution Summary:")
    print(class_df.to_string(index=False))

    print("\n🔍 Potential Issues:")

    missing_val = class_df[class_df['Val Count'] == 0]
    if not missing_val.empty:
        print(f"- {len(missing_val)} classes missing in validation set")

    imbalance = class_df[
        (class_df['Train Count'] > 10 * class_df['Val Count']) |
        (class_df['Val Count'] > 10 * class_df['Train Count'])]
    if not imbalance.empty:
        print(f"- Significant train/val imbalance in {len(imbalance)} classes")

    rare_classes = class_df[class_df['Train Count'] + class_df['Val Count'] < 5]
    if not rare_classes.empty:
        print(f"- {len(rare_classes)} rare classes (<5 total samples)")


def create_yaml_config(dataset_path):
    yaml_content = f"""
path: {dataset_path}
train: {dataset_path}/train/images
val: {dataset_path}/val/images

# GTSDB 43 classes
names:
  0: Speed limit (20km/h)
  1: Speed limit (30km/h)
  2: Speed limit (50km/h)
  3: Speed limit (60km/h)
  4: Speed limit (70km/h)
  5: Speed limit (80km/h)
  6: End of speed limit (80km/h)
  7: Speed limit (100km/h)
  8: Speed limit (120km/h)
  9: No passing
  10: No passing for vehicles over 3.5 metric tons
  11: Right-of-way at next intersection
  12: Priority road
  13: Yield
  14: Stop
  15: No vehicles
  16: Vehicles over 3.5 metric tons prohibited
  17: No entry
  18: General caution
  19: Dangerous curve to the left
  20: Dangerous curve to the right
  21: Double curve
  22: Bumpy road
  23: Slippery road
  24: Road narrows on the right
  25: Road work
  26: Traffic signals
  27: Pedestrians
  28: Children crossing
  29: Bicycles crossing
  30: Beware of ice/snow
  31: Wild animals crossing
  32: End of all speed and passing limits
  33: Turn right ahead
  34: Turn left ahead
  35: Ahead only
  36: Go straight or right
  37: Go straight or left
  38: Keep right
  39: Keep left
  40: Roundabout mandatory
  41: End of no passing
  42: End of no passing by vehicles over 3.5 metric tons
"""
    config_path = os.path.join(dataset_path, "gtsdb.yaml")
    with open(config_path, 'w') as f:
        f.write(yaml_content)
    print(f"✅ YAML config created at {config_path}")
    return config_path


def train_model(config_path):
    device = '0' if torch.cuda.is_available() else 'cpu'
    print(f"\n🚀 Training on {'GPU' if device != 'cpu' else 'CPU'}")

    model = YOLO("yolov8m.pt")

    results = model.train(
        data=config_path,
        epochs=80,
        imgsz=640,
        batch=16 if device != 'cpu' else 8,
        device=device,
        optimizer='Adam',
        lr0=0.001,
        patience=10,
        workers=4 if device != 'cpu' else 0,
        verbose=True,

        degrees=0.0,
        translate=0.1,
        scale=0.5,
        shear=0.0,
        perspective=0.0,
        flipud=0.0,
        fliplr=0.5,
    )

    return results


if __name__ == "__main__":
    print("🚀 Preparing dataset...")
    dataset_path = prepare_gtsdb_dataset()

    print("\n🔍 Analyzing dataset...")
    analyze_dataset(dataset_path)

    print("\n📄 Creating YAML config...")
    config_path = create_yaml_config(dataset_path)

    print("\n🏋️ Training model...")
    train_results = train_model(config_path)

    print("\n🎉 Training completed successfully!")
# Out:
# 🚀 Preparing dataset...
# ✅ Dataset preparation complete! Processed: 506, Skipped: 0
#
# 🔍 Analyzing dataset...
#
# 📊 Dataset Analysis:
# TRAIN: 455 images, 455 label files
# VAL: 51 images, 51 label files
#
# 🔢 Class Distribution:
#
# Class Distribution Summary:
#  Class ID  Train Count  Val Count
#         0            3          1
#         1           43          5
#         2           57          2
#         3           17          4
#         4           29          2
#         5           34          3
#         6           15          2
#         7           33          4
#         8           40          7
#         9           29          3
#        10           56          7
#        11           23          3
#        12           52          2
#        13           46          6
#        14           18          4
#        15           10          0
#        16            7          0
#        17           25          0
#        18           21          6
#        19            1          1
#        20            7          2
#        21            5          0
#        22            8          1
#        23           11          2
#        24            1          1
#        25           21          0
#        26           11          0
#        27            3          0
#        28            6          3
#        29            4          0
#        30           12          2
#        31            1          0
#        32            3          0
#        33            9          4
#        34            7          2
#        35           13          2
#        36            7          1
#        37            1          0
#        38           52          5
#        39            4          0
#        40            7          0
#        41            6          0
#        42            7          0
#
# 🔍 Potential Issues:
# - 15 classes missing in validation set
# - Significant train/val imbalance in 20 classes
# - 9 rare classes (<5 total samples)
#
# 📄 Creating YAML config...
# ✅ YAML config created at /content/gtsdb_yolo/gtsdb.yaml
#
# 🏋️ Training model...
#
# 🚀 Training on CPU
# Ultralytics 8.3.127 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/gtsdb_yolo/gtsdb.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=80, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=Adam, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Overriding model.yaml nc=80 with nc=43
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3800593  ultralytics.nn.modules.head.Detect           [43, [192, 384, 576]]
# Model summary: 169 layers, 25,881,217 parameters, 25,881,201 gradients, 79.2 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 476.0±621.9 MB/s, size: 140.8 KB)
# train: Scanning /content/gtsdb_yolo/train/labels.cache... 455 images, 0 backgrounds, 0 corrupt: 100%|██████████| 455/455 [00:00<?, ?it/s]
# train: /content/gtsdb_yolo/train/images/00340.jpg: 1 duplicate labels removed
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 824.8±779.2 MB/s, size: 140.1 KB)
# val: Scanning /content/gtsdb_yolo/val/labels.cache... 51 images, 0 backgrounds, 0 corrupt: 100%|██████████| 51/51 [00:00<?, ?it/s]
# Plotting labels to runs/detect/train2/labels.jpg...
# optimizer: Adam(lr=0.001, momentum=0.937) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80         0G      1.893      10.86      1.095         30        640:   2%|▏         | 1/57 [00:56<52:56, 56.72s/it]

# %%
backup_dir = "/content/drive/MyDrive/yolov8_gtsdb_backup"
os.makedirs(backup_dir, exist_ok=True)

source_folder = "/content/runs"
zip_path = "/content/runs_backup"

shutil.make_archive(zip_path, 'zip', source_folder)

shutil.copy(f"{zip_path}.zip", backup_dir)

print("✅ Zipped 'runs' folder uploaded to Google Drive!")
# Out:
# ✅ Zipped 'runs' folder uploaded to Google Drive!
